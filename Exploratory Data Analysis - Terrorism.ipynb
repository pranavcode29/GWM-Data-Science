# %% [markdown]
# # Groww With Code Internship program
#
# # Intermediate Level Task by Pranav Bansal
#
# # Exploratory Data Analysis on Dataset - Terrorism

# %% [markdown]
# The dataset that is going to be used is 'Gloabal Terrorism' from Kaggle. In this we have to analyse the data with the help of python libraries i.e..
#
# Numpy and Pandas for Mathematical and Statistical Functions
#
# Matplotlib and Seaborn for Data Visualization
#
# Also, As a security/defense analyst, try to find out the hot zone of terrorism.

# %% [markdown]
# # Data Preparation

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_palette('husl')

import warnings
warnings.filterwarnings("ignore")

# %%
# Loading the Data
terrorism = pd.read_csv("/content/globalterrorismdb_0718dist.csv",encoding='latin1')
terrorism
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
# Showing First 5 Rows
terrorism.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
# Showing Last 5 Rows
terrorism.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
# Showing no. of rows and columns in adataset
terrorism.shape
# Out:
# (181691, 135)

# %%
# Showing Columns of the Data
for i in terrorism.columns:
  print(i)
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# ...

# %% [markdown]
# # Data Preprocessing and Data Cleaning

# %%
# Showing Data Types of the columns
terrorism.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %% [markdown]
# There are so many Columns . So, we will extract only Important Columns which have more use in Data Analysis and Visualization.

# %%
# Extracting Important Columns
terrorism = terrorism[['iyear','imonth','iday','country_txt','provstate','region_txt',
                       'attacktype1_txt','target1','nkill','nwound','summary','gname',
                       'targtype1_txt','weaptype1_txt','motive']]

# %%
# Checking for columns
terrorism.columns
# Out:
# Index(['iyear', 'imonth', 'iday', 'country_txt', 'provstate', 'region_txt',
#        'attacktype1_txt', 'target1', 'nkill', 'nwound', 'summary', 'gname',
#        'targtype1_txt', 'weaptype1_txt', 'motive'],
#       dtype='object')

# %%
# Renaming of Columns
terrorism.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'State',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
terrorism.head(2)
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
#
#                     AttackType                   Target  Killed  Wounded  \
# 0                Assassination             Julio Guzman     1.0      0.0
# 1  Hostage Taking (Kidnapping)  Nadine Chaval, daughter     0.0      0.0
#
#   Summary                               Group                  Target_type  \
# 0     NaN                              MANO-D  Private Citizens & Property
# 1     NaN  23rd of September Communist League      Government (Diplomatic)
#
#   Weapon_type Motive
# 0     Unknown    NaN
# 1     Unknown    NaN

# %%
# Checking for duplicated values
terrorism.duplicated().sum()
# Out:
# 10095

# %% [markdown]
# terrorism.drop_duplicates(inplace=True)
# terrorism.shape

# %%
# Checking for duplicated values
terrorism.duplicated().any()
# Out:
# True

# %%
# Checking No. of unique values in the columns
terrorism.nunique()
# Out:
# Year               47
# Month              13
# Day                32
# Country           205
# State            2855
# Region             12
# AttackType          9
# Target          86006
# Killed            205
# Wounded           238
# Summary        112492
# Group            3537
# Target_type        22
# Weapon_type        12
# Motive          14490
# dtype: int64

# %% [markdown]
# # Null Values Treatment

# %%
# Checking for null values
terrorism.isna().sum().sort_values()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# Region              0
# AttackType          0
# Group               0
# Target_type         0
# Weapon_type         0
# State             421
# Target            636
# Killed          10313
# Wounded         16311
# Summary         66129
# Motive         131130
# dtype: int64

# %%
# Counting Values of State Column
terrorism['State'].value_counts()
# Out:
# Baghdad                  7645
# Northern Ireland         4498
# Unknown                  4290
# Balochistan              3710
# Saladin                  3411
#                          ...
# Federal Territory           1
# Topaz (Province)            1
# Obilic (Municipality)       1
# East Timor (Region)         1
# Vidzeme                     1
# Name: State, Length: 2855, dtype: int64

# %%
# Treating Null Values in State Column
terrorism['State'] = terrorism['State'].replace({'Unknown': np.nan})
terrorism['State'] = terrorism['State'].fillna("Others")
terrorism['State'].value_counts()
# Out:
# Baghdad                  7645
# Others                   4711
# Northern Ireland         4498
# Balochistan              3710
# Saladin                  3411
#                          ...
# Federal Territory           1
# Topaz (Province)            1
# Obilic (Municipality)       1
# East Timor (Region)         1
# Vidzeme                     1
# Name: State, Length: 2855, dtype: int64

# %%
# Checking for null values
terrorism['State'].isna().any()
# Out:
# False

# %%
# Counting values for Target Column
terrorism['Target'].value_counts()
# Out:
# Civilians                  6461
# Unknown                    5918
# Soldiers                   3157
# Patrol                     2942
# Checkpoint                 2905
#                            ...
# Manager Sanat Raj             1
# Military/ Police patrol       1
# Thor 67 Outpost               1
# Employee's Vehicle            1
# Hmeymim Air Base              1
# Name: Target, Length: 86006, dtype: int64

# %%
# Treating Null Values in Target Column
terrorism['Target'] = terrorism['Target'].replace({'Unknown': np.nan})
terrorism['Target'] = terrorism['Target'].fillna("Others")
terrorism['Target'].value_counts()
# Out:
# Others                     6554
# Civilians                  6461
# Soldiers                   3157
# Patrol                     2942
# Checkpoint                 2905
#                            ...
# Manager Sanat Raj             1
# Military/ Police patrol       1
# Thor 67 Outpost               1
# Employee's Vehicle            1
# Hmeymim Air Base              1
# Name: Target, Length: 86006, dtype: int64

# %%
# Checking for null values
terrorism['Target'].isnull().any()
# Out:
# False

# %% [markdown]
# Handling Null Values in KIlled and Wounded column

# %%
# Counting Values for Killed Column and Wounded Column
print(terrorism['Killed'].value_counts())
print(terrorism['Wounded'].value_counts())
# Out:
# 0.0      88149
# 1.0      36576
# 2.0      14147
# 3.0       7738
# 4.0       4961
#          ...
# 275.0        1
# 320.0        1
# 104.0        1
# 271.0        1
# 311.0        1
# Name: Killed, Length: 205, dtype: int64
# 0.0      103275
# 1.0       16033
# 2.0       10219
# 3.0        7303
# 4.0        4880
#           ...
# 727.0         1
# 216.0         1
# 751.0         1
# 233.0         1
# 316.0         1
# Name: Wounded, Length: 238, dtype: int64

# %%
# Checking for Outliers in Killed and Wouded Column
terrorism[['Killed','Wounded']].plot(kind='box')
# Out:
# <Axes: >

# %%
# Treating Null Values in Killed and Wounded Column with median
terrorism[['Killed', 'Wounded']] = terrorism[['Killed', 'Wounded']].fillna(terrorism[['Killed', 'Wounded']].mean())
terrorism[['Killed','Wounded']].isnull().any()
# Out:
# Killed     False
# Wounded    False
# dtype: bool

# %% [markdown]
# Summary and Motive Column are having so many null values . So, we will drop null values of 'Summary' and 'Motive' Column.

# %%
# Dropping Null Values of Summary and Motive Column
terrorism = terrorism.dropna(subset=['Summary'])
terrorism = terrorism.dropna(subset=['Motive'])

# %%
# Checking for null values
terrorism[['Summary','Motive']].isna().any()
# Out:
# Summary    False
# Motive     False
# dtype: bool

# %%
# checking Unique Values of Day Column
terrorism['Day'].unique()
# Out:
# array([ 1,  2,  3,  6,  9, 12, 13, 19, 22, 25, 26, 27, 30,  4,  8, 15, 16,
#        17, 21, 23, 24,  5, 10, 11, 14, 20, 31,  0, 29,  7, 18, 28])

# %% [markdown]
# Here 0 is also considered as Day which is not in actual so we will replace this value with Nan and drop this Nan Value

# %%
# Changing Data of Day Column
terrorism['Day'] = terrorism['Day'].replace(0,np.nan)
terrorism = terrorism.dropna(subset=['Day'])

# Checking no. of unique values in Day Column
print(terrorism['Day'].nunique())

# Checking for null values
print(terrorism['Day'].isnull().any())
# Out:
# 31
# False

# %%
# Checking for Null Values
terrorism.isnull().sum()
# Out:
# Year           0
# Month          0
# Day            0
# Country        0
# State          0
# Region         0
# AttackType     0
# Target         0
# Killed         0
# Wounded        0
# Summary        0
# Group          0
# Target_type    0
# Weapon_type    0
# Motive         0
# dtype: int64

# %%
terrorism.head(2)
# Out:
#    Year  Month  Day        Country      State         Region  \
# 5  1970      1  1.0  United States   Illinois  North America
# 8  1970      1  2.0  United States  Wisconsin  North America
#
#                        AttackType  \
# 5                   Armed Assault
# 8  Facility/Infrastructure Attack
#
#                                               Target  Killed  Wounded  \
# 5                          Cairo Police Headquarters     0.0      0.0
# 8  R.O.T.C. offices at University of Wisconsin, M...     0.0      0.0
#
#                                              Summary               Group  \
# 5  1/1/1970: Unknown African American assailants ...  Black Nationalists
# 8  1/2/1970: Karl Armstrong, a member of the New ...     New Year's Gang
#
#   Target_type Weapon_type                                          Motive
# 5      Police    Firearms  To protest the Cairo Illinois Police Deparment
# 8    Military  Incendiary     To protest the War in Vietnam and the draft

# %%
# Resetting index
terrorism.reset_index(inplace=True,drop=True)
terrorism.head()
# Out:
#    Year  Month  Day        Country        State         Region  \
# 0  1970      1  1.0  United States     Illinois  North America
# 1  1970      1  2.0  United States    Wisconsin  North America
# 2  1970      1  3.0  United States    Wisconsin  North America
# 3  1970      1  6.0  United States     Colorado  North America
# 4  1970      1  9.0  United States  Puerto Rico  North America
#
#                        AttackType  \
# 0                   Armed Assault
# 1  Facility/Infrastructure Attack
# 2  Facility/Infrastructure Attack
# 3  Facility/Infrastructure Attack
# 4  Facility/Infrastructure Attack
#
#                                               Target  Killed  Wounded  \
# 0                          Cairo Police Headquarters     0.0      0.0
# 1  R.O.T.C. offices at University of Wisconsin, M...     0.0      0.0
# 2  Selective Service Headquarters in Madison Wisc...     0.0      0.0
# 3           Army Recruiting Station, Denver Colorado     0.0      0.0
# ...

# %%
# Showing Information about the Dataset
terrorism.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50272 entries, 0 to 50271
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         50272 non-null  int64
#  1   Month        50272 non-null  int64
#  2   Day          50272 non-null  float64
#  3   Country      50272 non-null  object
#  4   State        50272 non-null  object
#  5   Region       50272 non-null  object
#  6   AttackType   50272 non-null  object
#  7   Target       50272 non-null  object
#  8   Killed       50272 non-null  float64
#  9   Wounded      50272 non-null  float64
#  10  Summary      50272 non-null  object
#  11  Group        50272 non-null  object
#  12  Target_type  50272 non-null  object
#  13  Weapon_type  50272 non-null  object
#  14  Motive       50272 non-null  object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 5.8+ MB

# %%
# Showing Categoical Columns
terrorism_cat = terrorism.select_dtypes(include=['object']).columns.tolist()
terrorism_cat
# Out:
# ['Country',
#  'State',
#  'Region',
#  'AttackType',
#  'Target',
#  'Summary',
#  'Group',
#  'Target_type',
#  'Weapon_type',
#  'Motive']

# %%
# Showing Numerical Columns
terrorism_num = terrorism.select_dtypes(exclude=['object']).columns.tolist()
terrorism_num
# Out:
# ['Year', 'Month', 'Day', 'Killed', 'Wounded']

# %%
# Showing Statistical Summary of Numerical Columns
terrorism.describe()
# Out:
#                Year         Month           Day        Killed       Wounded
# count  50272.000000  50272.000000  50272.000000  50272.000000  50272.000000
# mean    2007.929086      6.476170     15.323679      2.792769      4.875276
# std        6.490121      3.386636      8.782594     16.213658     57.495279
# min     1970.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2005.000000      4.000000      8.000000      0.000000      0.000000
# 50%     2009.000000      6.000000     15.000000      1.000000      0.000000
# 75%     2011.000000      9.000000     23.000000      2.000000      3.167668
# max     2017.000000     12.000000     31.000000   1570.000000   8191.000000

# %%
# showing Summary of Categorical Columns
terrorism.describe(include='O')
# Out:
#        Country    State      Region         AttackType     Target  \
# count    50272    50272       50272              50272      50272
# unique     165     1907          12                  9      34385
# top       Iraq  Baghdad  South Asia  Bombing/Explosion  Civilians
# freq      9469     3762       16788              24727       2476
#
#                                                   Summary    Group  \
# count                                               50272    50272
# unique                                              49429     1430
# top     01/11/2016: Assailants set fire to a shop in M...  Unknown
# freq                                                   36    24772
#
#                         Target_type Weapon_type   Motive
# count                         50272       50272    50272
# unique                           22          12    14387
# top     Private Citizens & Property  Explosives  Unknown
# freq                          15291       25987    14793

# %% [markdown]
# # Data Visualization

# %%
terrorism.hist(figsize=(10,10))
plt.show()

# %% [markdown]
# # 1. Year Column

# %% [markdown]
# 1. Attacks Per Year

# %%
# Plotting Countplot to show Attacks per Year
plt.figure(figsize=(15,5))
sns.countplot(x = terrorism['Year'])
plt.title('Terrorist Activities per Year')
plt.xlabel('Attacking Years')
plt.ylabel('No. of Attacks per Years')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Insights
# 1. Generally, as the Time proceeds the Number of Terrorists Attacks also Increased.
# 2. The peak in terms of Number of Terrorists Attacks was observed in 2011.
# 3. A Decline in terms of Number of Terrorists Attacks has been observed since 2014 which shows the progress towards the mission of reducing such terrorists attacks.

# %% [markdown]
# 2. No. of People Killed per Year

# %%
# Showing Peoples Kiled Per Year
kill_per_year = terrorism[['Year','Killed']].groupby('Year').sum()
kill_per_year.plot(kind='bar', figsize=(15,5), title = 'No. of People Killed Per Year')
plt.xlabel('Attacking Years')
plt.ylabel('No.of Peoples Killed ')
plt.show()

# %% [markdown]
# Insights
# 1. Generally, as the Time proceeds the Number of People Harmed Killed  also Increased Significantly.
# 2. The peak in terms of Number of People Harmed was observed in 2007.

# %% [markdown]
# 3 No. of People Wounded Per Year

# %%
wounded_per_year = terrorism[['Year','Wounded']].groupby('Year').sum()
wounded_per_year.plot(kind='bar', figsize=(15,5), title = 'No. of People Wounded Per Year')
plt.xlabel('Attacking Years')
plt.ylabel('No.of Peoples Wounded')
plt.show()

# %% [markdown]
# Insights
# 1. As the time proceeds the Number of People Wounded also Increased Significantly.
# 2. The peak in terms of Number of People Harmed was observed in 2001.
# 3. Though there has been a decline in the Number of People Harmed after 2007 but these numbers are still very large and need to be reduced as soon as possible.

# %% [markdown]
# # 2. Month Column

# %% [markdown]
# 1. Attacks Per Month

# %%
terrorism['Month'].value_counts().plot(kind='bar', title = 'Terrorist Activities per Month')
plt.xlabel('Attacking Months')
plt.ylabel('No. of Attacks per Month')
plt.show()

# %% [markdown]
# Insights
# 1. The most number of attacks takes place in November.
# 2. No. of People Wounded and Killed Per Month

# %%
kill_wounded_per_month = terrorism[['Killed','Wounded','Month']].groupby('Month').sum()
kill_wounded_per_month.plot(kind='bar', title = 'No. Of People Killed and Wounded Each Month')
plt.xlabel('Attacking Months')
plt.ylabel('No. of People Killed and wounded')
plt.show()

# %% [markdown]
# Insights
# 1. The most number of people were killed in August.
# 2. The most number of People were Wounded in September.

# %% [markdown]
# # 3. Day Column

# %%
plt.figure(figsize=(15,5))
sns.countplot(x = terrorism['Day'])
plt.title('Terrorist Activities per Day')
plt.xlabel('Attacking Days')
plt.ylabel('No. of Attacks per Day')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 4. Country Column

# %% [markdown]
# Top 20 Countries Which are Mostly Attacked

# %%
plt.figure(figsize=(15,5))
most_attack_countries = terrorism['Country'].value_counts().head(20)
most_attack_countries.plot(kind='bar')
plt.title('Top 20 Mostly Attacked Countries')
plt.xlabel('Countries')
plt.ylabel('No. of Attacks')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Insights
# 1. The above image shows the Top 20 countries in terms of most number of terrorist attacks.
# 2. The top country which is most affected by terrorist attacks is Iraq.
# 3. The top 5 countries most affected by terrorist attacks are Iraq, India, Pakistan, Afganistan, and Phillipines.

# %% [markdown]
# # 5. State Column

# %% [markdown]
# Top 10 Mostly Attacked States

# %%
plt.figure(figsize=(15,10))
most_attack_countries = terrorism['State'].value_counts().head(10)
most_attack_countries.plot(kind='pie',autopct = '%.2f%%')
plt.title('Top 10 Mostly Attacked States')
plt.xlabel('States')
plt.ylabel(None)
plt.show()

# %% [markdown]
# Insights
# 1. The above image shows the Top 10 States in terms of most number of terrorist attacks.
# 2. The top State which is most affected by terrorist attacks is Baghdad with the ratio of 30.34 % to the Other States.
# 3. The top 5 States most affected by terrorist attacks are Baghdad, Balochistan, Nineveh, Jammu and Kashmir, and Diyale.

# %% [markdown]
# # 6. Region Column

# %% [markdown]
# Top 7 Most Affected Regions by Terrorist  Attacks

# %%
plt.figure(figsize=(10,5))
most_attack_regions = terrorism['Region'].value_counts().head(7)
most_attack_regions.plot(kind='bar')
plt.title('Top 7 Mostly Attacked Regions')
plt.xlabel('Regions')
plt.ylabel('No. of Attacks')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Insights
# 1. The above image shows the Top Regions in terms of most number of Terrorist Attacks.
# 2. The most affected Region by terrorist attacks is South Asia.
# 3. The top 5 Regions most affected by terrorist attacks are South Asia,  Middle East & North Africa, Southeast Asia, Sub-Saharan Africa, Western Europe.

# %% [markdown]
# # AttackType Column

# %% [markdown]
# Types of Attack Types Used

# %%
# Plotting Most Used Attacks Types by Terrorist
plt.figure(figsize=(10,5))
most_attack_regions = terrorism['AttackType'].value_counts()
most_attack_regions.plot(kind='bar')
plt.title('Most Used Attack Types By Terrorists')
plt.xlabel('Type of Attacks')
plt.ylabel('No. of Terrorist Attacks')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Insights
# 1. The above image shows the Most Used Attack Types by Terrorists.
# 2. The Most Used Attack Type by Terrorists is Bombing/Explosion.
# 3. The top 5 Attack Types used by Terrorists are Bombing/Explosion, Armed Assault, Hostage Taking (Kidnapping), Facility/Infrastructure Attack and  Assassination.

# %% [markdown]
# # Target Column

# %%
terrorism['Target'].value_counts()
# Out:
# Civilians                                                      2476
# Others                                                         1594
# Soldiers                                                        243
# Officers                                                        238
# Checkpoint                                                      206
#                                                                ...
# A former warlord, Payanda Mohammad Khan, and his companions       1
# Istanbul civilians                                                1
# Mourners at a funeral in Abu Saida                                1
# Two Shi i mosques in Khanaqin                                     1
# Migrant Center                                                    1
# Name: Target, Length: 34385, dtype: int64

# %% [markdown]
# Top 10 Most Target Peoples by Terrorists Attacks

# %%
plt.figure(figsize=(10,5))
most_target_peoples = terrorism['Target'].value_counts().head(10)
most_target_peoples.plot(kind='bar')
plt.title('Most Target Peoples by Terrorists Attacks')
plt.xlabel('Most Target Peoples')
plt.ylabel('No. of Terrorists Attacks')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Insights
# 1. The above image shows the Most Target Peoples by the Terrorists Attacks.
# 2. Civillians are the most targeted by Terrorists.

# %% [markdown]
# # Group Column

# %% [markdown]
# Groups with Most Terrorists Attacks.

# %%
terr_groups = terrorism['Group'].value_counts()
terr_groups
# Out:
# Unknown                                           24772
# Taliban                                            2112
# Communist Party of India - Maoist (CPI-Maoist)     1689
# Islamic State of Iraq and the Levant (ISIL)         993
# Revolutionary Armed Forces of Colombia (FARC)       918
#                                                   ...
# Rebellious Group Lambros Foundas                      1
# Enyele Militia                                        1
# People's Democratic Struggle Movement                 1
# Angola Rebels                                         1
# Fatoni Warriors                                       1
# Name: Group, Length: 1430, dtype: int64

# %%
# Plotting Top 10 Groups Most Terrorist Attacks
fig = plt.figure(figsize=(15,5))
sns.barplot(x= terr_groups[1:11].index, y = terr_groups[1:11].values)
plt.title('Groups with Most Terrorist Attacks')
plt.xlabel('Terrorist Groups')
plt.ylabel('Number of Terrorist Attacks')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Insights
# 1. The above image shows the top Groups with Most No. of Terrorist Attacks.
# 2. The Terrorist Group with Most No. of Terrorist Attacks is Taliban.
# 3. The top 5 Groups with Most No. of Terrorist Attacks are  'Taliban',
#  'Communist Party of India - Maoist (CPI-Maoist)', 'Islamic State of Iraq and the Levant (ISIL)', 'Revolutionary Armed Forces of Colombia (FARC)', and 'New People's Army(NPA).

# %% [markdown]
# # Target Type Column

# %% [markdown]
# Most Frequent Targets of Terrorists.

# %%
targets = terrorism['Target_type'].value_counts()
targets
# Out:
# Private Citizens & Property       15291
# Government (General)               7261
# Police                             6217
# Business                           5353
# Military                           4244
# Transportation                     2073
# Religious Figures/Institutions     1823
# Educational Institution            1721
# Utilities                          1086
# Terrorists/Non-State Militia        838
# Government (Diplomatic)             812
# Journalists & Media                 796
# Unknown                             649
# Violent Political Party             499
# NGO                                 405
# Telecommunication                   388
# Airports & Aircraft                 239
# Abortion Related                    199
# Tourists                            144
# Maritime                             88
# Food or Water Supply                 86
# Other                                60
# Name: Target_type, dtype: int64

# %%
fig = plt.figure(figsize=(15,6))
sns.barplot(x = targets.index, y = targets.values)
plt.title("Most frequent target types of terrorists")
plt.xlabel("Targets")
plt.ylabel("Number of Terrorist Attacks")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Insights
# 1. The above image shows the Most frequent target types of terrorists.
# 2. The Most frequent target type of terrorists is Private Citizens & Property.
# 3. The top 5 Most frequent target type of terrorists are 'Private Citizens & Property', 'Government (General)', 'Police', 'Business' and 'Millitary'.

# %% [markdown]
# # Weapon_type Column

# %% [markdown]
# Most Weapon Type Used

# %%
weapon_used = terrorism['Weapon_type'].value_counts().head()
weapon_used
# Out:
# Explosives    25987
# Firearms      15619
# Incendiary     3652
# Unknown        3296
# Melee          1343
# Name: Weapon_type, dtype: int64

# %%
fig = plt.figure(figsize=(15,5))
sns.barplot(y = weapon_used.index, x = weapon_used.values)
plt.title("Most Weapon Used")
plt.xlabel("Number of Terrorist Attacks")
plt.ylabel("Weapons")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Insights
# 1. The above image shows the Most weapon used for terrorist activites.
# 2. The Most frequent Weapon Used is Explosives.
# 3. The top 5 Most frequent weapons for terrorists activities are Explosives, Firearms, Incendiary, Melee and Some Unknown Weapons.

# %% [markdown]
# # Plotting Correlation Plot

# %%
sns.heatmap(terrorism.corr(),annot=True)
plt.show()

# %% [markdown]
# From this Plot we can observe that Killed and Wounded columns are highly correlated.

# %% [markdown]
# # Plotting PairPlot

# %%
sns.pairplot(terrorism)

# %% [markdown]
# # Gathering Insights From The Data

# %% [markdown]
# 1. Year with Most Number of Attacks - 2011
# 2. Year with Most Number of People Killed - 2007
# 3. Year with Most Number of People Wounded - 2001
# 4. Month with Most No. of Attacks - November
# 5. Month in which Most No. of People Killed - August
# 6. Month in which Most No. of People Wounded - September
# 7. Country with Most Attacks - Iraq
# 8. State with Most Attacks - Baghdad
# 9. Region with most Attacks - SouthAsia
# 10. Most frequent Target Types - Private Citizens and Property
# 11. Most Used Attack Types by terrorists - Bombing/Explosion
# 12. Most Targeted People - Civillians
# 13. Group with most nO. of attacks - Taliban
# 14. Most frequent Weapon Used - Explosives.
